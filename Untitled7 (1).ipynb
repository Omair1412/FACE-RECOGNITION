# %%
# import TensorFlow
import tensorflow as tf

# %%
# Import standard dependencies
import cv2
import os
import random
import numpy as np
from matplotlib import pyplot as plt

# %%
# Import tensorflow dependencies - Functional API
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Layer, Conv2D, Dense, MaxPooling2D, Input, Flatten
import tensorflow as tf

# %%
# Setup paths
POS_PATH = os.path.join('data', 'positive')
NEG_PATH = os.path.join('data', 'negative')
ANC_PATH = os.path.join('data', 'anchor')

# %%
# Avoid OOM errors by setting GPU Memory Consumption Growth
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus: 
    tf.config.experimental.set_memory_growth(gpu, True)

# %%
# Setup paths
POS_PATH = os.path.join('data', 'positive')
NEG_PATH = os.path.join('data', 'negative')
ANC_PATH = os.path.join('data', 'anchor')

# %%
# Make the directories
os.makedirs(POS_PATH)
os.makedirs(NEG_PATH)
os.makedirs(ANC_PATH)

# %%
os.listdir('drive/MyDrive/FACEID')
# Out:
# ['lfw.tgz', 'Data', 'lfw', 'Untitled7.ipynb']

# %%
# http://vis-www.cs.umass.edu/lfw/

# %%
import tarfile

# %%
lfw = "/content/drive/MyDrive/FACEID/lfw"

# %%
tf =tarfile.open("/content/drive/MyDrive/FACEID/lfw.tgz")

# %%
tf.extractall(r"/content/drive/MyDrive/FACEID")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# /usr/lib/python3.10/tarfile.py in makedir(self, tarinfo, targetpath)
#    2203             # later in _extract_member().
# -> 2204             os.mkdir(targetpath, 0o700)
#    2205         except FileExistsError:
#
# FileExistsError: [Errno 17] File exists: '/content/drive/MyDrive/FACEID/lfw/George_HW_Bush'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-cb895cb0d136> in <cell line: 1>()
# ----> 1 tf.extractall(r"/content/drive/MyDrive/FACEID")
#
# /usr/lib/python3.10/tarfile.py in extractall(self, path, members, numeric_owner)
#    2057                 tarinfo.mode = 0o700
#    2058             # Do not set_attrs directories, as we will do that further down
# ...

# %%
# Move LFW Images to the following repository data/negative
for directory in os.listdir(lfw):
    for file in os.listdir(os.path.join(lfw, directory)):
        EX_PATH = os.path.join(lfw, directory, file)
        NEW_PATH = os.path.join(NEG_PATH, file)

# %%
import shutil

# %%
print(NEG_PATH)
# Out:
# data/negative

# %%
 shutil.move(EX_PATH, NEW_PATH)
# Out:
# 'data/negative/Pa_Kou_Hang_0001.jpg'

# %%
for directory in os.listdir("/content/drive/MyDrive/FACEID/lfw"):
    for file in os.listdir(os.path.join('/content/drive/MyDrive/FACEID/lfw', directory)):
      print(os.path.join(NEG_PATH, file))
# Out:
# Streaming output truncated to the last 5000 lines.
# data/negative/Ray_Bradbury_0001.jpg
# data/negative/David_Tornberg_0001.jpg
# data/negative/Daniele_Hypolito_0001.jpg
# data/negative/Heather_Locklear_0001.jpg
# data/negative/Huang_Suey-Sheng_0001.jpg
# data/negative/Anderson_Varejao_0001.jpg
# data/negative/Jacqueline_Edwards_0001.jpg
# data/negative/Mark_Sisk_0001.jpg
# data/negative/John_Sweeney_0001.jpg
# data/negative/Edwin_Edwards_0001.jpg
# data/negative/Edwin_Edwards_0002.jpg
# data/negative/Edwin_Edwards_0003.jpg
# data/negative/Robert_DeFraites_0001.jpg
# data/negative/Robert_DeFraites_0002.jpg
# data/negative/Michael_Deutsch_0001.jpg
# data/negative/Mayumi_Moriyama_0001.jpg
# data/negative/Alejandro_Lopez_0001.jpg
# data/negative/Brenda_Magana_0001.jpg
# data/negative/Etta_James_0001.jpg
# data/negative/Antwun_Echols_0001.jpg
# data/negative/Mark_Andrew_0001.jpg
# data/negative/Andy_Warhol_0001.jpg
# data/negative/Michael_Hoffa_0001.jpg
# ...

# %%
# Import uuid library to generate unique image names
import uuid

# %%
os.path.join(ANC_PATH, '{}.jpg'.format(uuid.uuid1()))
# Out:
# 'data/anchor/93ffb448-f2a6-11ed-9787-0242ac1c000c.jpg'

# %%
# Establish a connection to the webcam
cap = cv2.VideoCapture(4)
while cap.isOpened(): 
    ret, frame = cap.read()

# %%
 # Establish a connection to the webcam
cap = cv2.VideoCapture(4)
while cap.isOpened(): 
    ret, frame = cap.read()
    
     # Cut down frame to 250x250px
    frame = frame[120:120+250,200:200+250, :]
    
    # Collect anchors 
    if cv2.waitKey(1) & 0XFF == ord('a'):
        # Create the unique file path 
        imgname = os.path.join(ANC_PATH, '{}.jpg'.format(uuid.uuid1()))
        # Write out anchor image
        cv2.imwrite(imgname, frame)
    
    # Collect positives
    if cv2.waitKey(1) & 0XFF == ord('p'):
        # Create the unique file path 
        imgname = os.path.join(POS_PATH, '{}.jpg'.format(uuid.uuid1()))
        # Write out positive image
        cv2.imwrite(imgname, frame)
    
    # Show image back to screen
    cv2.imshow('Image Collection', frame)
    
    # Breaking gracefully
    if cv2.waitKey(1) & 0XFF == ord('q'):
        break
        
# Release the webcam
cap.release()
# Close the image show frame
cv2.destroyAllWindows()

# %%
from tkinter import Frame as frame
from tkinter import Text
from tkinter import Label

# %%
plt.imshow(frame[120:370,200:450, :])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-fd5009e3e81d> in <cell line: 1>()
# ----> 1 plt.imshow(frame[120:370,200:450, :])
#
# TypeError: 'type' object is not subscriptable

# %%
cv2.waitKey??
